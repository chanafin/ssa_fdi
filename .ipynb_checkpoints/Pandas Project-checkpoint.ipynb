# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

from config import local_db_user, local_db_pwd, local_db_endpoint, local_db_port, local_db_name
from config import remote_db_endpoint, remote_db_port, remote_db_user, remote_db_pwd, remote_db_name

# %%
local_engine = create_engine(f"postgresql://{local_db_user}:{local_db_pwd}@{local_db_endpoint}:{local_db_port}")
local_conn = local_engine.connect()

# %%
cloud_engine = create_engine(f"postgresql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
cloud_conn = cloud_engine.connect()

# %%
fdi = "data/fdi.csv"
fdi_df = pd.read_csv(fdi)
fdi_df.head()
# Out:
#    id country_name country_code series           2000             2001  \
# 0   0       Angola          AGO    FDI  $878,620,000   $2,145,470,000
# 1   0     Botswana          BWA    FDI   $57,171,313      $30,680,474
# 2   0      Burundi          BDI    FDI   $11,683,246         ($11,441)
# 3   0     DR Congo          COD    FDI   $94,190,400     $102,221,900
# 4   0         Chad          TCD    FDI  $115,172,422     $459,866,392
#
#               2002             2003             2004              2005  ...  \
# 0  $1,743,504,000   $3,576,971,780   $2,197,227,820   ($1,303,836,930)  ...
# 1    $407,997,829     $418,040,912     $390,889,365      $420,853,646   ...
# 2            $-               $-            $44,691          $584,702   ...
# 3    $187,598,694     $391,254,724     $409,032,815      $180,000,000   ...
# 4    $924,119,210     $712,663,455     $466,793,492      ($99,342,519)  ...
#
#               2009              2010              2011              2012  \
# ...

# %%
stability = "data/political_stability.csv"
stability_df = pd.read_csv(stability)

# %%
corruption = "data/corruption.csv"
corruption_df = pd.read_csv(corruption)
corruption_df
# Out:
#     id              country_name country Code            series   2000   2001  \
# 0    9                    Angola          AGO  Corruption Index  17.00    NaN
# 1    9                     Benin          BEN  Corruption Index    NaN    NaN
# 2    9                  Botswana          BWA  Corruption Index  60.00  60.00
# 3    9              Burkina Faso          BFA  Corruption Index  30.00    NaN
# 4    9                   Burundi          BDI  Corruption Index    NaN    NaN
# 5    9                Cape Verde          CPV  Corruption Index    NaN    NaN
# 6    9                  Cameroon          CMR  Corruption Index  20.00  20.00
# 7    9  Central African Republic          CAF  Corruption Index    NaN    NaN
# 8    9                      Chad          TCD  Corruption Index    NaN    NaN
# 9    9                   Comoros          COM  Corruption Index    NaN    NaN
# 10   9                     Congo          COG  Corruption Index    NaN    NaN
# ...

# %%
education = "data/education.csv"
education_df = pd.read_csv(education)
education_df.head()
# Out:
#    id  country_name country_code           series  2000  2001  2002  2003  \
# 0   7        Angola          AGO  Education Index  0.29   0.3  0.31  0.32
# 1   7         Benin          BEN  Education Index  0.27  0.29  0.31  0.32
# 2   7      Botswana          BWA  Education Index  0.59   0.6   0.6   0.6
# 3   7  Burkina Faso          BFA  Education Index  0.14  0.14  0.15  0.15
# 4   7       Burundi          BDI  Education Index  0.19  0.19   0.2  0.21
#
#    2004  2005  ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0  0.34  0.35  ...   0.4  0.40  0.42  0.44  0.45  0.46  0.47  0.49  0.50  0.50
# 1  0.33  0.34  ...  0.39  0.40  0.41  0.43  0.45  0.46  0.47  0.47  0.47  0.48
# 2  0.61  0.61  ...  0.63  0.64  0.64  0.65  0.65  0.65  0.66  0.66  0.66  0.66
# 3  0.16  0.17  ...  0.22  0.23  0.25  0.25  0.26  0.26  0.28  0.29  0.30  0.30
# 4  0.23  0.24  ...  0.36  0.38  0.39  0.40  0.41  0.42  0.42  0.43  0.41  0.42
#
# [5 rows x 23 columns]

# %%
gdp = "data/gdp.csv"
gdp_df = pd.read_csv(gdp)
gdp_df.head()
# Out:
#    id  country_name country_code series             2000             2001  \
# 0   1        Angola          AGO    GDP  $9,129,594,819   $8,936,063,723
# 1   1         Benin          BEN    GDP  $3,511,248,900   $3,663,017,700
# 2   1      Botswana          BWA    GDP  $5,788,329,609   $5,489,608,300
# 3   1  Burkina Faso          BFA    GDP  $2,956,746,304   $3,187,582,125
# 4   1       Burundi          BDI    GDP    $870,486,066     $876,794,723
#
#                2002              2003              2004              2005  \
# 0  $15,285,594,828   $17,812,705,294   $23,552,052,408   $36,970,918,699
# 1   $4,174,634,520    $5,337,266,688    $6,179,176,459    $6,565,043,460
# 2   $5,438,857,107    $7,511,582,173    $8,957,467,707    $9,931,134,941
# 3   $3,605,329,547    $4,730,140,785    $5,441,918,269    $6,143,909,201
# 4     $825,394,490      $784,654,424      $915,257,323    $1,117,113,046
#
#    ...              2009              2010               2011  \
# ...

# %%
humandev = "data/human_development.csv"
humandev_df = pd.read_csv(humandev)
humandev_df.head()
# Out:
#    id  country_name country_code                   series   2000   2001  \
# 0   6        Angola          AGO  Human Development Index  0.394  0.404
# 1   6         Benin          BEN  Human Development Index  0.398   0.41
# 2   6      Botswana          BWA  Human Development Index  0.578   0.58
# 3   6  Burkina Faso          BFA  Human Development Index  0.286   0.29
# 4   6       Burundi          BDI  Human Development Index  0.293  0.294
#
#     2002   2003   2004   2005  ...   2009   2010   2011   2012   2013   2014  \
# 0  0.419  0.428   0.44  0.453  ...  0.508  0.510  0.525  0.537  0.547  0.557
# 1  0.419  0.426  0.434   0.44  ...  0.468  0.473  0.479  0.489  0.500  0.505
# 2  0.576  0.583  0.589  0.598  ...  0.647  0.660  0.676  0.687  0.699  0.709
# 3  0.296  0.303  0.312  0.324  ...  0.366  0.375  0.385  0.394  0.401  0.405
# 4  0.304  0.312  0.322  0.329  ...  0.391  0.402  0.410  0.416  0.422  0.429
#
#     2015   2016   2017   2018
# 0  0.565  0.570  0.576  0.574
# ...

# %%
life = "data/life_expectancy_ssa.csv"
life_df = pd.read_csv(life)
life_df.head()
# Out:
#    id  country_name country_code           series  2000  2001  2002  2003  \
# 0   5        Angola          AGO  Life Expectancy  46.5  47.1  47.7  48.4
# 1   5         Benin          BEN  Life Expectancy  55.4  55.7  56.0  56.4
# 2   5      Botswana          BWA  Life Expectancy  50.6  50.3  50.2  50.5
# 3   5  Burkina Faso          BFA  Life Expectancy  50.5  50.9  51.4  52.0
# 4   5    Cape verde          CPV  Life Expectancy  68.6  69.1  69.6  69.9
#
#    2004  2005  ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0  49.3  50.2  ...  54.3  55.4  56.3  57.2  58.1  58.8  59.4  59.9  60.4  60.8
# 1  56.9  57.4  ...  59.0  59.3  59.6  59.8  60.1  60.3  60.6  60.9  61.2  61.5
# 2  51.2  52.1  ...  58.4  60.2  61.9  63.5  65.0  66.3  67.3  68.2  68.8  69.3
# 3  52.6  53.3  ...  56.4  57.1  57.8  58.4  58.9  59.5  59.9  60.4  60.8  61.2
# 4  70.2  70.4  ...  70.9  71.1  71.2  71.4  71.7  71.9  72.1  72.3  72.6  72.8
#
# [5 rows x 23 columns]

# %%
life_agg = "data/Life Expectancy Aggregates.csv"
life_agg_df = pd.read_csv(life_agg)
life_agg_df.head()
# Out:
#       Country_Name Country Code   2000   2001   2002   2003   2004   2005  \
# 0    North America          NAC  76.88  77.08  77.19  77.30  77.72  77.75
# 1       South Asia          SAS  62.82  63.23  63.62  64.01  64.40  64.78
# 2            World          WLD  67.55  67.82  68.07  68.33  68.65  68.92
# 3       Low Income          LIC  53.58  54.11  54.69  55.31  55.96  56.63
# 4  Least Developed          LDC  55.48  55.98  56.50  57.06  57.65  58.26
#
#     2006   2007  ...   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0  77.95  78.24  ...  78.65  78.81  78.92  79.03  79.04  79.14  79.01  78.88
# 1  65.18  65.59  ...  66.43  66.85  67.26  67.65  68.01  68.34  68.64  68.92
# 2  69.26  69.59  ...  70.25  70.56  70.88  71.17  71.46  71.74  71.95  72.18
# 3  57.31  57.99  ...  59.29  59.88  60.43  60.95  61.45  61.91  62.35  62.76
# 4  58.88  59.52  ...  60.78  61.39  61.97  62.52  63.03  63.51  63.95  64.35
#
#     2017   2018
# 0  78.88  78.89
# 1  69.17  69.41
# ...

# %%
gdp_pc = "data/gdp_per_capita.csv"
gdp_pc_df = pd.read_csv(gdp_pc)
gdp_pc_df
# Out:
#     id              country_name country_code          series     2000  \
# 0    3                    Angola          AGO  GDP Per Capita    $557
# 1    3                     Benin          BEN  GDP Per Capita    $511
# 2    3                  Botswana          BWA  GDP Per Capita  $3,522
# 3    3              Burkina Faso          BFA  GDP Per Capita    $255
# 4    3                   Burundi          BDI  GDP Per Capita    $136
# 5    3                Cape Verde          CPV  GDP Per Capita  $1,259
# 6    3                  Cameroon          CMR  GDP Per Capita    $650
# 7    3  Central African Republic          CAF  GDP Per Capita    $251
# 8    3                      Chad          TCD  GDP Per Capita    $166
# 9    3                   Comoros          COM  GDP Per Capita    $646
# 10   3                  DR Congo          COD  GDP Per Capita    $405
# 11   3                     Congo          COG  GDP Per Capita  $1,030
# ...

# %%
health_gdp = "data/health_expenditure_per_gdp.csv"
health_gdp_df = pd.read_csv(health_gdp)
health_gdp_df.head()
# Out:
#    id country_name country_code              series  2000  2001  2002  2003  \
# 0   4       Angola          AGO  Health Expenditure  1.91  4.48  3.33  3.55
# 1   4        Benin          BEN  Health Expenditure  4.23  4.43  4.15  4.15
# 2   4     Botswana          BWA  Health Expenditure  5.83  6.16  6.42  6.18
# 3   4      Burundi          BDI  Health Expenditure  6.18   6.4  6.47  6.31
# 4   4   Cape Verde          CPV  Health Expenditure  4.43  4.75  4.76   4.5
#
#    2004  2005  ...   2009   2010   2011  2012  2013  2014  2015  2016  2017  \
# 0  3.97  2.85  ...   3.84    2.7   2.65   2.4  2.73  2.43  2.61  2.71  2.79
# 1   4.2  4.01  ...   3.86   4.09   4.22  4.67  3.91  3.65  3.99  3.86  3.72
# 2   5.8  5.03  ...   6.53   6.19   5.78  6.14  6.22   5.6  5.73  5.56  6.13
# 3   7.7  8.42  ...  10.35  11.28  10.07  8.53  8.14  6.89  6.58  7.49  7.52
# 4  4.38  4.27  ...   3.88   4.48   4.31  5.13  5.29  5.33  4.82  4.84  5.17
#
#   2018
# 0   ..
# 1   ..
# 2   ..
# 3   ..
# 4   ..
# ...

# %%
gni = "data/gni_per_capita.csv"
gni_df = pd.read_csv(gni)
gni_df.head()
# Out:
#    id country_name country_code          series     2000     2001     2002  \
# 0   2       Angola          AGO  GNI Per Capita    $360     $390     $590
# 1   2        Benin          BEN  GNI Per Capita    $480     $530     $530
# 2   2     Botswana          BWA  GNI Per Capita  $3,170   $3,260   $2,930
# 3   2      Burundi          BDI  GNI Per Capita    $130     $130     $130
# 4   2   Cape Verde          CPV  GNI Per Capita  $1,410   $1,350   $1,300
#
#       2003     2004     2005  ...     2009     2010     2011     2012  \
# 0    $710   $1,010   $1,370   ...  $3,170   $3,240   $3,420   $4,170
# 1    $600     $730     $820   ...  $1,080   $1,080   $1,090   $1,120
# 2  $3,370   $3,920   $4,940   ...  $5,330   $5,610   $6,610   $7,260
# 3    $120     $120     $140   ...    $200     $220     $230     $250
# 4  $1,520   $1,900   $2,160   ...  $3,480   $3,400   $3,510   $3,440
#
#       2013     2014     2015     2016     2017     2018
# ...

# %%
try:
    local_conn.execution_options(isolation_level="AUTOCOMMIT").execute(f"CREATE DATABASE {local_db_name}")
except Exception as e:
    print(e)
try:
    local_engine = create_engine(f"postgresql://{local_db_user}:{local_db_pwd}@{local_db_endpoint}:{local_db_port}/{local_db_name}")
    local_conn = local_engine.connect()
except Exception as e:
    print(e)
local_engine.table_names()
# Out:
# (psycopg2.errors.DuplicateDatabase) database "fdi_test" already exists
#
# [SQL: CREATE DATABASE FDI_Test]
# (Background on this error at: http://sqlalche.me/e/f405)
# ['life',
#  'gdp_pc',
#  'gni',
#  'health_gdp',
#  'life_agg',
#  'fdi',
#  'stability',
#  'corruption',
#  'education',
#  'gdp',
#  'humandev']

# %%
# gni_df.to_sql(name = 'gni', if_exists = 'replace', con = local_conn, index = False)
# health_gdp_df.to_sql(name = 'health_gdp', if_exists = 'replace', con = local_conn, index = False)
# gdp_pc_df.to_sql(name = 'gdp_pc', if_exists = 'replace', con = local_conn, index = False)
# life_agg_df.to_sql(name = 'life_agg', if_exists = 'replace', con = local_conn, index = False)
# fdi_df.to_sql(name='fdi', con = local_engine, if_exists='replace', index=False)
stability_df.to_sql(name='stability', con = local_engine, if_exists='replace', index=False)
# corruption_df.to_sql(name='corruption', con = local_engine, if_exists='replace', index=False)
# education_df.to_sql(name='education', con = local_engine, if_exists='replace', index=False)
# gdp_df.to_sql(name='gdp', con = local_engine, if_exists='replace', index=False)
# humandev_df.to_sql(name='humandev', con = local_engine, if_exists='replace', index=False)
# life_df.to_sql(name='life', con = local_engine, if_exists='replace', index=False)

# %%
# life_agg_df.to_sql(name = 'life_agg', con = cloud_conn, if_exists = 'replace', index = False)
# gni_df.to_sql(name = 'gni', if_exists = 'replace', con = cloud_conn, index = False)
# health_gdp_df.to_sql(name = 'health_gdp', if_exists = 'replace', con = cloud_conn, index = False)
# gdp_pc_df.to_sql(name = 'gdp_pc', if_exists = 'replace', con = cloud_conn, index = False)
# fdi_df.to_sql(name ='fdi', if_exists ='replace', con = cloud_conn, chunksize=500, index=False)
stability_df.to_sql(name ='stability', if_exists ='replace', con = cloud_conn, chunksize=500, index=False)
# corruption_df.to_sql(name ='corruption', if_exists ='replace', con = cloud_conn, chunksize=500, index=False)
# education_df.to_sql(name ='education', if_exists ='replace', con = cloud_conn, chunksize=500, index=False)
# gdp_df.to_sql(name ='gdp', if_exists ='replace', con = cloud_conn, chunksize=500, index=False)
# humandev_df.to_sql(name ='humandev', if_exists ='replace', con = cloud_conn, chunksize=500, index=False)
# life_df.to_sql(name ='life', if_exists ='replace', con = cloud_conn, chunksize=500, index=False)
